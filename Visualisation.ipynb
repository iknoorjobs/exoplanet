# %%
import numpy as np
import pandas as pd
import plotly.graph_objs as go

from subprocess import check_output
import matplotlib.pyplot as plt
import plotly.plotly as py

# %%
extrain= pd.read_csv('exoTrain.csv')
extest=pd.read_csv('exoTest.csv')

# %%
extrain.shape
# Out:
# (5087, 3198)

# %%
extrain.head()
# Out:
#    LABEL   FLUX.1   FLUX.2   FLUX.3   FLUX.4   FLUX.5   FLUX.6  FLUX.7  \
# 0      2    93.85    83.81    20.10   -26.98   -39.56  -124.71 -135.18
# 1      2   -38.88   -33.83   -58.54   -40.09   -79.31   -72.81  -86.55
# 2      2   532.64   535.92   513.73   496.92   456.45   466.00  464.50
# 3      2   326.52   347.39   302.35   298.13   317.74   312.70  322.33
# 4      2 -1107.21 -1112.59 -1118.95 -1095.10 -1057.55 -1034.48 -998.34
#
#     FLUX.8  FLUX.9    ...      FLUX.3188  FLUX.3189  FLUX.3190  FLUX.3191  \
# 0   -96.27  -79.89    ...         -78.07    -102.15    -102.15      25.13
# 1   -85.33  -83.97    ...          -3.28     -32.21     -32.21     -24.89
# 2   486.39  436.56    ...         -71.69      13.31      13.31     -29.89
# 3   311.31  312.42    ...           5.71      -3.73      -3.73      30.05
# 4 -1022.71 -989.57    ...        -594.37    -401.66    -401.66    -357.24
#
#    FLUX.3192  FLUX.3193  FLUX.3194  FLUX.3195  FLUX.3196  FLUX.3197
# ...

# %%
extrain.loc[extrain['LABEL'] == 2].shape
# Out:
# (37, 3198)

# %%
#  somme histograms of data with labels 2  
labels_2=[1,5,8,12,16,21,25]
for i in labels_2:
    plt.hist(extrain.iloc[i,:], bins=200)
    plt.title("Histogram")
    plt.xlabel("Flux values")
    plt.show()

# %%
labels_1=[100,200,300,450,640,632]
for i in labels_1:
    plt.hist(extrain.iloc[i,:], bins=200)
    plt.title("Gaussian Histogram")
    plt.xlabel("Flux values")
    plt.show()

# %%
for i in [0,1,2,3,4]:
    Y = extrain.iloc[i]
    X = np.arange(len(Y)) 
    plt.figure(figsize=(15,5))
    plt.ylabel('Flux')
    plt.xlabel('Observation')
    plt.plot(X, Y)
    plt.show()

# %%
for i in [j for j in range (139,142)]:    
    Y = extrain.iloc[i]
    X = np.arange(len(Y)) 
    plt.figure(figsize=(15,5))
    plt.ylabel('Flux')
    plt.xlabel('Observation')
    plt.plot(X, Y)
    plt.show()

# %%
def normal(X):
    Y= (X-np.mean(X))/(np.max(X)-np.min(X))
    return Y

# %%
extrain= extrain.apply(normal,axis=1)

# %%
for i in [0,1,2,3,4]:
    Y = extrain.iloc[i]
    X = np.arange(len(Y)) 
    plt.figure(figsize=(15,5))
    plt.ylabel('Flux')
    plt.xlabel('Observation')
    plt.plot(X, Y)
    plt.show()
